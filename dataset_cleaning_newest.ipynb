# %%
#!kaggle datasets download lokeshparab/amazon-products-dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset/amazon_product_worked.csv')
df.head()
# Out:
#    Unnamed: 0                                               name  \
# 0           0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1           1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2           2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3           3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4           4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#   main_category      sub_category  \
# 0    appliances  Air Conditioners
# 1    appliances  Air Conditioners
# 2    appliances  Air Conditioners
# 3    appliances  Air Conditioners
# 4    appliances  Air Conditioners
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
# ...

# %%
df = df.drop(['Unnamed: 0', 'image', 'link'], axis=1)
df.head()
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
#
#        sub_category ratings no_of_ratings discount_price actual_price
# 0  Air Conditioners     4.2         2,255        ₹32,999      ₹58,990
# 1  Air Conditioners     4.2         2,948        ₹46,490      ₹75,990
# 2  Air Conditioners     4.2         1,206        ₹34,490      ₹61,990
# 3  Air Conditioners     4.0            69        ₹37,990      ₹68,990
# 4  Air Conditioners     4.1           630        ₹34,490      ₹67,790

# %%
df.tail(10)
# Out:
#                                                      name     main_category  \
# 551575       Just Rider Compression Clothing (XXL, Black)  sports & fitness
# 551576  PANCHTATAVA Yoga Mat Cover with Adjustable Sho...  sports & fitness
# 551577  Obsessions Reversible Printed Yoga Mat,Anti-Sl...  sports & fitness
# 551578                              Puma Women Sweatshirt  sports & fitness
# 551579  BE SAVAGE Pink I Purple You Hoodie Suitable fo...  sports & fitness
# 551580                Adidas Regular Fit Men's Track Tops  sports & fitness
# 551581          Redwolf Noice Toit Smort - Hoodie (Black)  sports & fitness
# 551582     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)  sports & fitness
# 551583                                    Puma Men Shorts  sports & fitness
# 551584  Mothercare Printed Cotton Elastane Girls Infan...  sports & fitness
#
#        sub_category ratings no_of_ratings discount_price actual_price
# ...

# %%
empty_actual_price = df[df['actual_price'].isnull()]
empty_actual_price
# Out:
#                                                      name     main_category  \
# 76      LG 1.5 Ton 3 Star Hot & Cold DUAL Inverter Spl...        appliances
# 100     Hitachi 1.5 Ton 5 Star Inverter Split AC (Copp...        appliances
# 114     Panasonic 1.5 Ton 4 Star Wi-Fi Twin-Cool Inver...        appliances
# 144     Daikin 1.5 Ton 4 Star Hot & Cold Heat Pump Inv...        appliances
# 146     LG 1.5 Ton 5 Star AI DUAL Inverter Wi-Fi Split...        appliances
# ...                                                   ...               ...
# 551371  Workout Knee Cushion, Crush Resistance Compact...  sports & fitness
# 551402  Tom & Jerry by Wear Your Mind Unisex-Child Hoo...  sports & fitness
# 551410                Mode By Red Tape Women Black Hoodie  sports & fitness
# 551471                  Campus Sutra Women Printed Hoodie  sports & fitness
# 551583                                    Puma Men Shorts  sports & fitness
#
# ...

# %%
empty_discount_price = df[df['discount_price'].isnull()]
empty_discount_price
# Out:
#                                                      name     main_category  \
# 76      LG 1.5 Ton 3 Star Hot & Cold DUAL Inverter Spl...        appliances
# 100     Hitachi 1.5 Ton 5 Star Inverter Split AC (Copp...        appliances
# 114     Panasonic 1.5 Ton 4 Star Wi-Fi Twin-Cool Inver...        appliances
# 126     Hitachi 1.5 Ton 5 Star Window AC (Copper, Dust...        appliances
# 137     Portable Air Conditioner,Office Air Conditione...        appliances
# ...                                                   ...               ...
# 551535  Nivia 2367-3 Hydra-2 Polyester Training Tee, A...  sports & fitness
# 551536  Nivia 2365-3 Hydra-1 Polyester Training Tee, A...  sports & fitness
# 551542                                  Adidas Men's Flat  sports & fitness
# 551567       Adidas Women's Cotton Hooded Neck Sweatshirt  sports & fitness
# 551583                                    Puma Men Shorts  sports & fitness
#
# ...

# %%
df = df.dropna(subset=['actual_price'])
df. head()
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
#
#        sub_category ratings no_of_ratings discount_price actual_price
# 0  Air Conditioners     4.2         2,255        ₹32,999      ₹58,990
# 1  Air Conditioners     4.2         2,948        ₹46,490      ₹75,990
# 2  Air Conditioners     4.2         1,206        ₹34,490      ₹61,990
# 3  Air Conditioners     4.0            69        ₹37,990      ₹68,990
# 4  Air Conditioners     4.1           630        ₹34,490      ₹67,790

# %%
empty_actual_price = df[df['actual_price'].isnull()]
empty_actual_price
# Out:
# Empty DataFrame
# Columns: [name, main_category, sub_category, ratings, no_of_ratings, discount_price, actual_price]
# Index: []

# %%
empty_discount_price = df[df['discount_price'].isnull()]
empty_discount_price
# Out:
#                                                      name     main_category  \
# 126     Hitachi 1.5 Ton 5 Star Window AC (Copper, Dust...        appliances
# 137     Portable Air Conditioner,Office Air Conditione...        appliances
# 207     Voltas 1.5 Ton 3 Star Window AC (Copper 183CYA...        appliances
# 212     FANCISUN Portable Air Conditioner,Personal Air...        appliances
# 213     BENBOAR Portable Air Conditioner Fan, Desktop ...        appliances
# ...                                                   ...               ...
# 551526  Nivia 2434 Polyester Women Jacket, X-Large (Tu...  sports & fitness
# 551535  Nivia 2367-3 Hydra-2 Polyester Training Tee, A...  sports & fitness
# 551536  Nivia 2365-3 Hydra-1 Polyester Training Tee, A...  sports & fitness
# 551542                                  Adidas Men's Flat  sports & fitness
# 551567       Adidas Women's Cotton Hooded Neck Sweatshirt  sports & fitness
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 533772 entries, 0 to 551584
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            533772 non-null  object
#  1   main_category   533772 non-null  object
#  2   sub_category    533772 non-null  object
#  3   ratings         369030 non-null  object
#  4   no_of_ratings   369030 non-null  object
#  5   discount_price  490422 non-null  object
#  6   actual_price    533772 non-null  object
# dtypes: object(7)
# memory usage: 32.6+ MB

# %%
# check for duplicates in name
duplicates = df[df.duplicated(['name'], keep=False)]
duplicates
# Out:
#                                                      name     main_category  \
# 0       Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 1       LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...        appliances
# 2       LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...        appliances
# 3       LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...        appliances
# 4       Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...        appliances
# ...                                                   ...               ...
# 551561  More & More Dancing Panda Printed Unisex Hoodi...  sports & fitness
# 551562  More & More Dancing Panda Printed Unisex Hoodi...  sports & fitness
# 551568                              Adidas Men's Standard  sports & fitness
# 551572                Amazon Brand - Symactive Men Shorts  sports & fitness
# 551578                              Puma Women Sweatshirt  sports & fitness
#
# ...

# %%
df = df.drop_duplicates(subset=['name'], keep='first')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 384827 entries, 0 to 551584
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            384827 non-null  object
#  1   main_category   384827 non-null  object
#  2   sub_category    384827 non-null  object
#  3   ratings         263093 non-null  object
#  4   no_of_ratings   263093 non-null  object
#  5   discount_price  350961 non-null  object
#  6   actual_price    384827 non-null  object
# dtypes: object(7)
# memory usage: 23.5+ MB

# %%
df = df.reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384827 entries, 0 to 384826
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            384827 non-null  object
#  1   main_category   384827 non-null  object
#  2   sub_category    384827 non-null  object
#  3   ratings         263093 non-null  object
#  4   no_of_ratings   263093 non-null  object
#  5   discount_price  350961 non-null  object
#  6   actual_price    384827 non-null  object
# dtypes: object(7)
# memory usage: 20.6+ MB

# %%
df.head()
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
#
#        sub_category ratings no_of_ratings discount_price actual_price
# 0  Air Conditioners     4.2         2,255        ₹32,999      ₹58,990
# 1  Air Conditioners     4.2         2,948        ₹46,490      ₹75,990
# 2  Air Conditioners     4.2         1,206        ₹34,490      ₹61,990
# 3  Air Conditioners     4.0            69        ₹37,990      ₹68,990
# 4  Air Conditioners     4.1           630        ₹34,490      ₹67,790

# %%
df['name'].loc[0]
# Out:
# 'Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1 Convertible, Copper, Anti-Viral + Pm 2.5 Filter, 2023 Model, White, Gls18I3...'

# %%
df['name'] = df['name'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384827 entries, 0 to 384826
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            384827 non-null  object
#  1   main_category   384827 non-null  object
#  2   sub_category    384827 non-null  object
#  3   ratings         263093 non-null  object
#  4   no_of_ratings   263093 non-null  object
#  5   discount_price  350961 non-null  object
#  6   actual_price    384827 non-null  object
# dtypes: object(7)
# memory usage: 20.6+ MB

# %%
truncated_names = df[df['name'].str.endswith('...')]
truncated_names
# Out:
#                                                      name     main_category  \
# 0       Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 1       LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...        appliances
# 2       LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...        appliances
# 3       LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...        appliances
# 6       Lloyd 1.0 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# ...                                                   ...               ...
# 384774  ADAM WHITE Unisex Printed Cotton Hoodies, Swea...  sports & fitness
# 384792  Fitventure Anti Skid Yoga Belt for Stretching ...  sports & fitness
# 384805  ManHood Men's Synthetic Lycra Regular Fit Stre...  sports & fitness
# 384816  ELEG & STILANCE Fitness Workout Shorts Women E...  sports & fitness
# 384821  Obsessions Reversible Printed Yoga Mat,Anti-Sl...  sports & fitness
#
# ...

# %%
truncated_names.head(10)
# Out:
#                                                  name main_category  \
# 0   Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1   LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2   LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3   LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 6   Lloyd 1.0 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 7   Lloyd 1.5 Ton 5 Star Inverter Split Ac (5 In 1...    appliances
# 8   Carrier 1 Ton 3 Star AI Flexicool Inverter Spl...    appliances
# 10  Daikin 1 Ton 3 Star Inverter Split AC (Copper,...    appliances
# 12  Panasonic 1.5 Ton 5 Star Wi-Fi Inverter Smart ...    appliances
# 13  Carrier 1.5 Ton 5 Star AI Flexicool Inverter S...    appliances
#
#         sub_category ratings no_of_ratings discount_price actual_price
# 0   Air Conditioners     4.2         2,255        ₹32,999      ₹58,990
# 1   Air Conditioners     4.2         2,948        ₹46,490      ₹75,990
# ...

# %%
dibuang = df[~df['name'].str.endswith('...')]
dibuang.head(10)
# Out:
#                                                  name main_category  \
# 4   Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
# 5   Voltas 1.4 Ton 3 Star Inverter Split AC(Copper...    appliances
# 9   Voltas 1.5 Ton, 5 Star, Inverter Split AC(Copp...    appliances
# 11  Daikin 1.5 Ton 5 Star Inverter Split AC (Coppe...    appliances
# 18  Godrej 1 Ton 3 Star Inverter Split Ac Model 20...    appliances
# 24  Lloyd 1.5 Ton 3 Star Fixed Speed Window Ac (Co...    appliances
# 26  Voltas 1.5 Ton 5 Star, Inverter Window AC (Cop...    appliances
# 36  Daikin 1 Ton 5 Star Inverter Split AC (Copper,...    appliances
# 41  Daikin 1.5 Ton 3 Star Fixed Speed Split AC (Co...    appliances
# 48  AmazonBasics 1.5 Ton 5 Star Inverter Split AC ...    appliances
#
#         sub_category ratings no_of_ratings discount_price actual_price
# 4   Air Conditioners     4.1           630        ₹34,490      ₹67,790
# 5   Air Conditioners     4.0         1,666        ₹31,990      ₹70,990
# ...

# %%
dibuang.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 294490 entries, 4 to 384826
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            294490 non-null  object
#  1   main_category   294490 non-null  object
#  2   sub_category    294490 non-null  object
#  3   ratings         198522 non-null  object
#  4   no_of_ratings   198522 non-null  object
#  5   discount_price  263792 non-null  object
#  6   actual_price    294490 non-null  object
# dtypes: object(7)
# memory usage: 18.0+ MB

# %%
df['name'] = df['name'].str.replace('...', ')', regex=False)
df.head()
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
#
#        sub_category ratings no_of_ratings discount_price actual_price
# 0  Air Conditioners     4.2         2,255        ₹32,999      ₹58,990
# 1  Air Conditioners     4.2         2,948        ₹46,490      ₹75,990
# 2  Air Conditioners     4.2         1,206        ₹34,490      ₹61,990
# 3  Air Conditioners     4.0            69        ₹37,990      ₹68,990
# 4  Air Conditioners     4.1           630        ₹34,490      ₹67,790

# %%
df.loc[0, 'name']
# Out:
# 'Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1 Convertible, Copper, Anti-Viral + Pm 2.5 Filter, 2023 Model, White, Gls18I3)'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384827 entries, 0 to 384826
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            384827 non-null  object
#  1   main_category   384827 non-null  object
#  2   sub_category    384827 non-null  object
#  3   ratings         263093 non-null  object
#  4   no_of_ratings   263093 non-null  object
#  5   discount_price  350961 non-null  object
#  6   actual_price    384827 non-null  object
# dtypes: object(7)
# memory usage: 20.6+ MB

# %%
df['main_category'] = df['main_category'].astype(str)
df['sub_category'] = df['sub_category'].astype(str)

# %%
# Check for missing values in main_category and sub_category
missing_main_category = df[df['main_category'].isnull()]
missing_sub_category = df[df['sub_category'].isnull()]
missing_main_category, missing_sub_category
# Out:
# (Empty DataFrame
#  Columns: [name, main_category, sub_category, ratings, no_of_ratings, discount_price, actual_price]
#  Index: [],
#  Empty DataFrame
#  Columns: [name, main_category, sub_category, ratings, no_of_ratings, discount_price, actual_price]
#  Index: [])

# %%
# check for missing values in rating and no_of_ratings
missing_ratings = df[df['ratings'].isnull()]
missing_ratings
# Out:
#                                                      name     main_category  \
# 24      Lloyd 1.5 Ton 3 Star Fixed Speed Window Ac (Co...        appliances
# 50      Samsung 1 Ton 5 Star Inverter Split AC (Copper...        appliances
# 57      Haier 1.5 Ton 3 Star Frost Self Clean Inverter...        appliances
# 69      Lloyd 2.0 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 73      Voltas 1.5 Ton 3 Star, Fixed Speed Window AC (...        appliances
# ...                                                   ...               ...
# 384765  The Yogis Iyengar Wall Yoga Ropes full Set of ...  sports & fitness
# 384767  Men's Regular FIT Dont Quit Printed Cotton Hoodie  sports & fitness
# 384814  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384818  Just rider Arm Sleeves UV Protection for Drivi...  sports & fitness
# 384821  Obsessions Reversible Printed Yoga Mat,Anti-Sl...  sports & fitness
#
# ...

# %%
missing_no_of_ratings = df[df['no_of_ratings'].isnull()]
missing_no_of_ratings
# Out:
#                                                      name     main_category  \
# 24      Lloyd 1.5 Ton 3 Star Fixed Speed Window Ac (Co...        appliances
# 50      Samsung 1 Ton 5 Star Inverter Split AC (Copper...        appliances
# 57      Haier 1.5 Ton 3 Star Frost Self Clean Inverter...        appliances
# 69      Lloyd 2.0 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 73      Voltas 1.5 Ton 3 Star, Fixed Speed Window AC (...        appliances
# ...                                                   ...               ...
# 384765  The Yogis Iyengar Wall Yoga Ropes full Set of ...  sports & fitness
# 384767  Men's Regular FIT Dont Quit Printed Cotton Hoodie  sports & fitness
# 384814  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384818  Just rider Arm Sleeves UV Protection for Drivi...  sports & fitness
# 384821  Obsessions Reversible Printed Yoga Mat,Anti-Sl...  sports & fitness
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384827 entries, 0 to 384826
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            384827 non-null  object
#  1   main_category   384827 non-null  object
#  2   sub_category    384827 non-null  object
#  3   ratings         263093 non-null  object
#  4   no_of_ratings   263093 non-null  object
#  5   discount_price  350961 non-null  object
#  6   actual_price    384827 non-null  object
# dtypes: object(7)
# memory usage: 20.6+ MB

# %%
non_numeric_ratings = df[pd.to_numeric(df['ratings'], errors='coerce').isnull()]
non_numeric_ratings
# Out:
#                                                      name     main_category  \
# 24      Lloyd 1.5 Ton 3 Star Fixed Speed Window Ac (Co...        appliances
# 50      Samsung 1 Ton 5 Star Inverter Split AC (Copper...        appliances
# 57      Haier 1.5 Ton 3 Star Frost Self Clean Inverter...        appliances
# 69      Lloyd 2.0 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 73      Voltas 1.5 Ton 3 Star, Fixed Speed Window AC (...        appliances
# ...                                                   ...               ...
# 384799  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384800  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384814  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384818  Just rider Arm Sleeves UV Protection for Drivi...  sports & fitness
# 384821  Obsessions Reversible Printed Yoga Mat,Anti-Sl...  sports & fitness
#
# ...

# %%
# Define a function to replace specific strings with NaN
def replace_with_nan(x):
    if isinstance(x, str) and (
        x.startswith("Get") or x.startswith("Free") or x.startswith("FREE") or x.startswith("₹")
    ):
        return np.nan
    else:
        return x

# Apply the function to the 'ratings' column
df['ratings'] = df['ratings'].apply(replace_with_nan)

# Verify the changes
df['ratings'].head()
# Out:
# 0    4.2
# 1    4.2
# 2    4.2
# 3    4.0
# 4    4.1
# Name: ratings, dtype: object

# %%
df['ratings'] = df['ratings'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384827 entries, 0 to 384826
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            384827 non-null  object
#  1   main_category   384827 non-null  object
#  2   sub_category    384827 non-null  object
#  3   ratings         257527 non-null  float64
#  4   no_of_ratings   263093 non-null  object
#  5   discount_price  350961 non-null  object
#  6   actual_price    384827 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 20.6+ MB

# %%
df.head(10)
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
# 5  Voltas 1.4 Ton 3 Star Inverter Split AC(Copper...    appliances
# 6  Lloyd 1.0 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 7  Lloyd 1.5 Ton 5 Star Inverter Split Ac (5 In 1...    appliances
# 8  Carrier 1 Ton 3 Star AI Flexicool Inverter Spl...    appliances
# 9  Voltas 1.5 Ton, 5 Star, Inverter Split AC(Copp...    appliances
#
#        sub_category  ratings no_of_ratings discount_price actual_price
# 0  Air Conditioners      4.2         2,255        ₹32,999      ₹58,990
# 1  Air Conditioners      4.2         2,948        ₹46,490      ₹75,990
# ...

# %%
# Find rows where 'no_of_ratings' contains non-numeric values
non_numeric_no_of_ratings = df[pd.to_numeric(df['no_of_ratings'], errors='coerce').isnull()]

# Display rows with non-numeric values in 'no_of_ratings'
non_numeric_no_of_ratings
# Out:
#                                                      name     main_category  \
# 0       Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 1       LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...        appliances
# 2       LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...        appliances
# 5       Voltas 1.4 Ton 3 Star Inverter Split AC(Copper...        appliances
# 6       Lloyd 1.0 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# ...                                                   ...               ...
# 384799  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384800  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384814  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384818  Just rider Arm Sleeves UV Protection for Drivi...  sports & fitness
# 384821  Obsessions Reversible Printed Yoga Mat,Anti-Sl...  sports & fitness
#
# ...

# %%
# Define a function to replace specific strings with random integers
def replace_with_nan_no_of_ratings(x):
    if isinstance(x, str) and (
        x.startswith("Usually dispatched") or x.startswith("Only") or x.startswith("Free") or x.startswith("This item") or x.startswith("FREE Delivery")
    ):
        return np.nan
    else:
        return x

# Apply the function to the 'no_of_ratings' column
df['no_of_ratings'] = df['no_of_ratings'].apply(replace_with_nan_no_of_ratings)

# %%
df['no_of_ratings'] = df['no_of_ratings'].str.replace(',', '')
df.head(10)
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
# 5  Voltas 1.4 Ton 3 Star Inverter Split AC(Copper...    appliances
# 6  Lloyd 1.0 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 7  Lloyd 1.5 Ton 5 Star Inverter Split Ac (5 In 1...    appliances
# 8  Carrier 1 Ton 3 Star AI Flexicool Inverter Spl...    appliances
# 9  Voltas 1.5 Ton, 5 Star, Inverter Split AC(Copp...    appliances
#
#        sub_category  ratings no_of_ratings discount_price actual_price
# 0  Air Conditioners      4.2          2255        ₹32,999      ₹58,990
# 1  Air Conditioners      4.2          2948        ₹46,490      ₹75,990
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384827 entries, 0 to 384826
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            384827 non-null  object
#  1   main_category   384827 non-null  object
#  2   sub_category    384827 non-null  object
#  3   ratings         257527 non-null  float64
#  4   no_of_ratings   257527 non-null  object
#  5   discount_price  350961 non-null  object
#  6   actual_price    384827 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 20.6+ MB

# %%
df['no_of_ratings'] = pd.to_numeric(df['no_of_ratings'], errors='coerce')

# %%
df['no_of_ratings'] = df['no_of_ratings'].astype("Int64")

# %%
empty_no_of_ratings = df[df['no_of_ratings'].isna()]
empty_no_of_ratings
# Out:
#                                                      name     main_category  \
# 24      Lloyd 1.5 Ton 3 Star Fixed Speed Window Ac (Co...        appliances
# 50      Samsung 1 Ton 5 Star Inverter Split AC (Copper...        appliances
# 57      Haier 1.5 Ton 3 Star Frost Self Clean Inverter...        appliances
# 69      Lloyd 2.0 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 73      Voltas 1.5 Ton 3 Star, Fixed Speed Window AC (...        appliances
# ...                                                   ...               ...
# 384799  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384800  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384814  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384818  Just rider Arm Sleeves UV Protection for Drivi...  sports & fitness
# 384821  Obsessions Reversible Printed Yoga Mat,Anti-Sl...  sports & fitness
#
# ...

# %%
print("Min:", df['no_of_ratings'].min())
print("Max:", df['no_of_ratings'].max())
# Out:
# Min: 1
# Max: 589547

# %%
print(df[df['no_of_ratings'] == df['no_of_ratings'].max()])
# Out:
#                                                     name        main_category  \
# 52926  SanDisk 128GB Class 10 microSDXC Memory Card w...  tv, audio & cameras
# 53091  SanDisk 16GB Ultra MicroSDHC Memory Card (SDSQ...  tv, audio & cameras
# 53231  SanDisk Ultra 64GB UHS-I Class 10 Micro SD Mem...  tv, audio & cameras
# 53472  SanDisk UHS-I A1 98Mbps 32GB Ultra MicroSD Mem...  tv, audio & cameras
# 54557  SanDisk 256GB Class 10 MicroSD Card with Adapt...  tv, audio & cameras
# 58425  SanDisk 400GB Class 10 MicroSD Card (SDSQUAR-4...  tv, audio & cameras
# 59992  SanDisk 512GB Ultra MicroSDXC UHS-I Memory Car...  tv, audio & cameras
#
#              sub_category  ratings  no_of_ratings discount_price actual_price
# 52926  Camera Accessories      4.3         589547         ₹1,705       ₹3,999
# 53091  Camera Accessories      4.3         589547           ₹495         ₹500
# 53231  Camera Accessories      4.3         589547           ₹750       ₹1,000
# ...

# %%
df['ratings'].isna().sum()
# Out:
# np.int64(127300)

# %%
df[df['ratings'].isna()]
# Out:
#                                                      name     main_category  \
# 24      Lloyd 1.5 Ton 3 Star Fixed Speed Window Ac (Co...        appliances
# 50      Samsung 1 Ton 5 Star Inverter Split AC (Copper...        appliances
# 57      Haier 1.5 Ton 3 Star Frost Self Clean Inverter...        appliances
# 69      Lloyd 2.0 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 73      Voltas 1.5 Ton 3 Star, Fixed Speed Window AC (...        appliances
# ...                                                   ...               ...
# 384799  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384800  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384814  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384818  Just rider Arm Sleeves UV Protection for Drivi...  sports & fitness
# 384821  Obsessions Reversible Printed Yoga Mat,Anti-Sl...  sports & fitness
#
# ...

# %%
print("Min:", df['ratings'].min())
print("Max:", df['ratings'].max())
# Out:
# Min: 1.0
# Max: 5.0

# %%
print(df[df['ratings'] == df['ratings'].min()])
# Out:
#                                                      name     main_category  \
# 226     CARRIER SPLIT AC 1 TON 3 STAR FIX SPEED (12K 3...        appliances
# 262     Haier Frost Clean Inverter Split AC with 5 in ...        appliances
# 342     TOSHIBA 1.5 Ton 3 Star Inverter Split AC (Copp...        appliances
# 361     Samsung 1 Ton 3 Star Inverter Split AC (Alloy ...        appliances
# 438     Belity Portable Mini Air Conditioner Desktop A...        appliances
# ...                                                   ...               ...
# 384494                    HPS Sports Men's Regular Jacket  sports & fitness
# 384508  CHERRY CRUMBLE Blue Black Solid Fleece & Polar...  sports & fitness
# 384542     SXV STYLE The Unisex Printed Hoodie : Shinchan  sports & fitness
# 384570  Supreme Yoga Mat Printed With Sides Locking 24...  sports & fitness
# 384708  Eurofil Yoga Mat 4mm Anti Skid Yoga Mat For Ho...  sports & fitness
#
# ...

# %%
mode_rating = df['ratings'].mode()[0]  # Get the most frequent value
df['ratings'] = df['ratings'].fillna(mode_rating)

# %%
df[df['ratings'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, main_category, sub_category, ratings, no_of_ratings, discount_price, actual_price]
# Index: []

# %%
# check missing value in no_of_ratings
df[df['no_of_ratings'].isna()]
# Out:
#                                                      name     main_category  \
# 24      Lloyd 1.5 Ton 3 Star Fixed Speed Window Ac (Co...        appliances
# 50      Samsung 1 Ton 5 Star Inverter Split AC (Copper...        appliances
# 57      Haier 1.5 Ton 3 Star Frost Self Clean Inverter...        appliances
# 69      Lloyd 2.0 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 73      Voltas 1.5 Ton 3 Star, Fixed Speed Window AC (...        appliances
# ...                                                   ...               ...
# 384799  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384800  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384814  Amazon Brand - Symactive Men's Activewear Gym ...  sports & fitness
# 384818  Just rider Arm Sleeves UV Protection for Drivi...  sports & fitness
# 384821  Obsessions Reversible Printed Yoga Mat,Anti-Sl...  sports & fitness
#
# ...

# %%
# Calculate mode (most frequent value)
mode_value = df['no_of_ratings'].mode()[0]

# Fill missing (NaN) values with mode
df['no_of_ratings'] = df['no_of_ratings'].fillna(mode_value)

# %%
# check missing value in no_of_ratings
df[df['no_of_ratings'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, main_category, sub_category, ratings, no_of_ratings, discount_price, actual_price]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384827 entries, 0 to 384826
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            384827 non-null  object
#  1   main_category   384827 non-null  object
#  2   sub_category    384827 non-null  object
#  3   ratings         384827 non-null  float64
#  4   no_of_ratings   384827 non-null  Int64
#  5   discount_price  350961 non-null  object
#  6   actual_price    384827 non-null  object
# dtypes: Int64(1), float64(1), object(5)
# memory usage: 20.9+ MB

# %%
df.head()
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
#
#        sub_category  ratings  no_of_ratings discount_price actual_price
# 0  Air Conditioners      4.2           2255        ₹32,999      ₹58,990
# 1  Air Conditioners      4.2           2948        ₹46,490      ₹75,990
# 2  Air Conditioners      4.2           1206        ₹34,490      ₹61,990
# 3  Air Conditioners      4.0             69        ₹37,990      ₹68,990
# 4  Air Conditioners      4.1            630        ₹34,490      ₹67,790

# %%
df['discount_price'] = df['discount_price'].str.replace('[₹,]', '', regex=True)

# %%
df.head()
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
#
#        sub_category  ratings  no_of_ratings discount_price actual_price
# 0  Air Conditioners      4.2           2255          32999      ₹58,990
# 1  Air Conditioners      4.2           2948          46490      ₹75,990
# 2  Air Conditioners      4.2           1206          34490      ₹61,990
# 3  Air Conditioners      4.0             69          37990      ₹68,990
# 4  Air Conditioners      4.1            630          34490      ₹67,790

# %%
missing_discount_price = df[df['discount_price'].isnull()]
missing_discount_price
# Out:
#                                                      name     main_category  \
# 122     Hitachi 1.5 Ton 5 Star Window AC (Copper, Dust...        appliances
# 133     Portable Air Conditioner,Office Air Conditione...        appliances
# 193     Voltas 1.5 Ton 3 Star Window AC (Copper 183CYA...        appliances
# 198     FANCISUN Portable Air Conditioner,Personal Air...        appliances
# 199     BENBOAR Portable Air Conditioner Fan, Desktop ...        appliances
# ...                                                   ...               ...
# 384776  Head HBS-1091 Polyester Badminton Shorts, XX-S...  sports & fitness
# 384781  Nivia 2434 Polyester Women Jacket, X-Large (Tu...  sports & fitness
# 384790  Nivia 2367-3 Hydra-2 Polyester Training Tee, A...  sports & fitness
# 384791  Nivia 2365-3 Hydra-1 Polyester Training Tee, A...  sports & fitness
# 384813       Adidas Women's Cotton Hooded Neck Sweatshirt  sports & fitness
#
# ...

# %%
df['discount_price'] = pd.to_numeric(df['discount_price'], errors='coerce')

# %%
df['discount_price'] = df['discount_price'].round().astype('Int64')

# %%
missing_discount_price = df[df['discount_price'].isnull()]
missing_discount_price
# Out:
#                                                      name     main_category  \
# 122     Hitachi 1.5 Ton 5 Star Window AC (Copper, Dust...        appliances
# 133     Portable Air Conditioner,Office Air Conditione...        appliances
# 193     Voltas 1.5 Ton 3 Star Window AC (Copper 183CYA...        appliances
# 198     FANCISUN Portable Air Conditioner,Personal Air...        appliances
# 199     BENBOAR Portable Air Conditioner Fan, Desktop ...        appliances
# ...                                                   ...               ...
# 384776  Head HBS-1091 Polyester Badminton Shorts, XX-S...  sports & fitness
# 384781  Nivia 2434 Polyester Women Jacket, X-Large (Tu...  sports & fitness
# 384790  Nivia 2367-3 Hydra-2 Polyester Training Tee, A...  sports & fitness
# 384791  Nivia 2365-3 Hydra-1 Polyester Training Tee, A...  sports & fitness
# 384813       Adidas Women's Cotton Hooded Neck Sweatshirt  sports & fitness
#
# ...

# %%
# Calculate mode (most frequent value)
mode_discount = df['discount_price'].mode()[0]

# Fill missing (NaN) values with mode
df['discount_price'] = df['discount_price'].fillna(mode_discount)

# %%
missing_discount_price = df[df['discount_price'].isnull()]
missing_discount_price
# Out:
# Empty DataFrame
# Columns: [name, main_category, sub_category, ratings, no_of_ratings, discount_price, actual_price]
# Index: []

# %%
df.head(20)
# Out:
#                                                  name main_category  \
# 0   Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1   LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2   LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3   LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4   Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
# 5   Voltas 1.4 Ton 3 Star Inverter Split AC(Copper...    appliances
# 6   Lloyd 1.0 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 7   Lloyd 1.5 Ton 5 Star Inverter Split Ac (5 In 1...    appliances
# 8   Carrier 1 Ton 3 Star AI Flexicool Inverter Spl...    appliances
# 9   Voltas 1.5 Ton, 5 Star, Inverter Split AC(Copp...    appliances
# 10  Daikin 1 Ton 3 Star Inverter Split AC (Copper,...    appliances
# 11  Daikin 1.5 Ton 5 Star Inverter Split AC (Coppe...    appliances
# 12  Panasonic 1.5 Ton 5 Star Wi-Fi Inverter Smart ...    appliances
# ...

# %%
df['actual_price'] = df['actual_price'].str.replace('[₹,]', '', regex=True)

# %%
check_missing_actual_price = df[df['actual_price'].isnull()]
check_missing_actual_price
# Out:
# Empty DataFrame
# Columns: [name, main_category, sub_category, ratings, no_of_ratings, discount_price, actual_price]
# Index: []

# %%
df.head(10)
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
# 5  Voltas 1.4 Ton 3 Star Inverter Split AC(Copper...    appliances
# 6  Lloyd 1.0 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 7  Lloyd 1.5 Ton 5 Star Inverter Split Ac (5 In 1...    appliances
# 8  Carrier 1 Ton 3 Star AI Flexicool Inverter Spl...    appliances
# 9  Voltas 1.5 Ton, 5 Star, Inverter Split AC(Copp...    appliances
#
#        sub_category  ratings  no_of_ratings  discount_price actual_price
# 0  Air Conditioners      4.2           2255           32999        58990
# 1  Air Conditioners      4.2           2948           46490        75990
# ...

# %%
df['actual_price'] = pd.to_numeric(df['actual_price'], errors='coerce')

# %%
df['actual_price'] = df['actual_price'].round()

# %%
df['actual_price'] = df['actual_price'].astype("Int64")

# %%
df.head(10)
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
# 5  Voltas 1.4 Ton 3 Star Inverter Split AC(Copper...    appliances
# 6  Lloyd 1.0 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 7  Lloyd 1.5 Ton 5 Star Inverter Split Ac (5 In 1...    appliances
# 8  Carrier 1 Ton 3 Star AI Flexicool Inverter Spl...    appliances
# 9  Voltas 1.5 Ton, 5 Star, Inverter Split AC(Copp...    appliances
#
#        sub_category  ratings  no_of_ratings  discount_price  actual_price
# 0  Air Conditioners      4.2           2255           32999         58990
# 1  Air Conditioners      4.2           2948           46490         75990
# ...

# %%
# ganti ke IDR dari rupee
exchange_rate = 185.89
df['discount_price_idr'] = (df['discount_price'] * exchange_rate).round().astype('Int64')

# %%
df.head(10)
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
# 5  Voltas 1.4 Ton 3 Star Inverter Split AC(Copper...    appliances
# 6  Lloyd 1.0 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 7  Lloyd 1.5 Ton 5 Star Inverter Split Ac (5 In 1...    appliances
# 8  Carrier 1 Ton 3 Star AI Flexicool Inverter Spl...    appliances
# 9  Voltas 1.5 Ton, 5 Star, Inverter Split AC(Copp...    appliances
#
#        sub_category  ratings  no_of_ratings  discount_price  actual_price  \
# 0  Air Conditioners      4.2           2255           32999         58990
# 1  Air Conditioners      4.2           2948           46490         75990
# ...

# %%
df['actual_price_idr'] = (df['actual_price'] * exchange_rate).round().astype('Int64')
df.head(10)
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
# 5  Voltas 1.4 Ton 3 Star Inverter Split AC(Copper...    appliances
# 6  Lloyd 1.0 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 7  Lloyd 1.5 Ton 5 Star Inverter Split Ac (5 In 1...    appliances
# 8  Carrier 1 Ton 3 Star AI Flexicool Inverter Spl...    appliances
# 9  Voltas 1.5 Ton, 5 Star, Inverter Split AC(Copp...    appliances
#
#        sub_category  ratings  no_of_ratings  discount_price  actual_price  \
# 0  Air Conditioners      4.2           2255           32999         58990
# 1  Air Conditioners      4.2           2948           46490         75990
# ...

# %%
# remove discount_price and actual_price
df = df.drop(['discount_price', 'actual_price'], axis=1)
df.head(10)
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
# 5  Voltas 1.4 Ton 3 Star Inverter Split AC(Copper...    appliances
# 6  Lloyd 1.0 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 7  Lloyd 1.5 Ton 5 Star Inverter Split Ac (5 In 1...    appliances
# 8  Carrier 1 Ton 3 Star AI Flexicool Inverter Spl...    appliances
# 9  Voltas 1.5 Ton, 5 Star, Inverter Split AC(Copp...    appliances
#
#        sub_category  ratings  no_of_ratings  discount_price_idr  \
# 0  Air Conditioners      4.2           2255             6134184
# 1  Air Conditioners      4.2           2948             8642026
# ...

# %%
# adding stock column with random values from 50 - 500 using numpy
df['stock'] = np.random.randint(50, 500, size=len(df))
df.head(10)
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
# 5  Voltas 1.4 Ton 3 Star Inverter Split AC(Copper...    appliances
# 6  Lloyd 1.0 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 7  Lloyd 1.5 Ton 5 Star Inverter Split Ac (5 In 1...    appliances
# 8  Carrier 1 Ton 3 Star AI Flexicool Inverter Spl...    appliances
# 9  Voltas 1.5 Ton, 5 Star, Inverter Split AC(Copp...    appliances
#
#        sub_category  ratings  no_of_ratings  discount_price_idr  \
# 0  Air Conditioners      4.2           2255             6134184
# 1  Air Conditioners      4.2           2948             8642026
# ...

# %%
# create a new index column in the first position
df.insert(0, 'index', range(1, 1 + len(df)))
df.head(10)
# Out:
#    index                                               name main_category  \
# 0      1  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1      2  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2      3  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3      4  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4      5  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
# 5      6  Voltas 1.4 Ton 3 Star Inverter Split AC(Copper...    appliances
# 6      7  Lloyd 1.0 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 7      8  Lloyd 1.5 Ton 5 Star Inverter Split Ac (5 In 1...    appliances
# 8      9  Carrier 1 Ton 3 Star AI Flexicool Inverter Spl...    appliances
# 9     10  Voltas 1.5 Ton, 5 Star, Inverter Split AC(Copp...    appliances
#
#        sub_category  ratings  no_of_ratings  discount_price_idr  \
# 0  Air Conditioners      4.2           2255             6134184
# ...

# %%
df.to_csv('dataset/amazon_product_cleaned.csv', index=False)
